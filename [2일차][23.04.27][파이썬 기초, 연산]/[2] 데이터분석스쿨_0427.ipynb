# %% [markdown]
# #단축키

# %% [markdown]
# 1. **실행 단축키**
#     1. (필수) `Ctrl(Command)` + `Enter` : 해당 셀 실행
#     2. `Shift` + `Enter` : 해당 셀 실행 + 커서를 다음 셀로 이동
#     3. (필수) `Alt(Option)` + `Enter` : 해당 셀 실행 + 코드 불록 하단 추가
# 2. **셀 삽입/삭제 관련 단축키**
#     1. `Ctrl(Command)` + M A : 코드 셀 위에 삽입
#     2. `Ctrl(Command)` + M B : 코드 셀 아래 삽입
#     3. `Ctrl(Command)` + M D : 셀 지우기
#     4. `Ctrl(Command)` + M Y : 코드 셀로 변경
#     5. `Ctrl(Command)` + M M : 마크다운 셀로 변경
#     6. `Ctrl(Command)` + M Z : 실행 취소
# 3. 수정 관련된 단축키
#     1. `Ctrl(Command)` + `Alt(Option)` + 화살표위아래 : 동시 수정
#     2. (자주) `Ctrl(Command)` + D : 같은 단어 찾아 동시 수정
#     3. `Ctrl(Command)` + `Shift` + L : 동일 단어를 전체로 찾아 동시 수정
#     4. `Alt(Option)` + `Shift` + 화살표위아래 : 해당내용을 위나 아래 복사해서 붙여넣기
#     5. `Alt(Option)` + 화살표위아래 : 해당 내용을 위나 아래로 보내기
#     6. (자주) `Ctrl` + `Alt` + 화살표위아래 : 위아래 동시 수정
#     7. (자주) Home, End : 문장의 양 끝
#     8. (필수) `Ctrl` + `/` : 주석
#     9. (필수) `Ctrl` + `Del` : 한 줄 지우기
#     10. (필수) `Tab`, `Ctrl` + `]` : 들여쓰기
#     11. (필수) `Shift` + `Tab`, `Ctrl` + `[` : 내어쓰기
# 4. 단축키 보기 및 설정
#     1. `Ctrl(Command)` + M H : 단축키 모음

# %% [markdown]
# # 마크다운

# %% [markdown]
# * 마크업 (.html)
#   ```html
#   <h1>내 생에 첫 홈페이지</h1>
#   <h2>내 생에 첫 홈페이지</h2>
#   <p>hello world</p>
#   ```
#
# * 마크다운
#   ```
#   # hello
#   ## hello
#   ### hello
#   * hello -> 제목처럼 앞에 점이 찍힘
#   * hello
#   1.hello
#   2.hello
#   ```

# %% [markdown]
# # 데이터 분석 개론

# %% [markdown]
# * 데이터 분석(Data Analysis) : 유용한 정보를 발굴하고 결론적인 내용을 알리며 의사결정을 지원하는 것을 목표로 데이터를 정리, 변환, 모델링하는 과정
# * 데이터 유형
#   * 정량적 데이터
#     * 정형 데이터
#       * 데이터베이스
#       * 스프레드시트(exel, csv...)
#     * 반정형 데이터
#       * JSON -> [{},{}...] 리스트안에 딕셔너리(표준은 {[{},{}...]} 외부에 중괄호)
#       * HTML -> 웹사이트 표현 (마크업 언어)
#       * XML -> 웹사이트 표현 (마크업 언어, HTML과 유사하고 한계를 극복하기 위해 만들어졌지만, 극복하지 못함)
#   * 정성적 데이터
#     * 비정형 데이터
#       * 텍스트
#       * 음성
#       * 이미지

# %% [markdown]
# ## KDD 분석 절차

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 커리어
# * 데이터 분석가(Data Analyst) : 프로그래밍 기술을 갖추고 통계학을 이해하면서 정보를 시각적으로 잘 표현할 수 있는 사람
# * 데이터 사이언티스트(Data Scientist) : 논문 구현 또는 적용, 알고리즘 구현 또는 적용
# * 데이터 엔지니어(Data Engineer) : 데이터 로깅, 데이터 분석 파이프라인 구축, 데이터 사이언티스트가 내놓은 알고리즘을 실제 서비스에 반영하기도 함

# %% [markdown]
# ## 자격증
# * 빅데이터분석기사(6개월 준비)(1년에 2번)(정보처리기사보다 위상이 높음)
# * SQL 개발자(SQLD)
# * 데이터분석 준전문가(ADsP)

# %% [markdown]
# # GitHub

# %% [markdown]
# * GUI
#     1. Add file > Create new file
#     2. Add file > Upload files
#     3. . > VSC
#
# * CLI
#     1.  git clone https://github.com/weniv/DA_School_1.git .
#     2. git pull
#     3. <수정하고>
#     4. git add .
#     5. git commit -m '메시지'
#     6. git push.

# %% [markdown]
# # Python

# %% [markdown]
# ## 주석

# %%
# 주석 : 코드를 보류하거나
# 해당 코드에 대한 설명을 할 경우

# 행 단위 주석입니다.

# 열
# 단위 
# 주석입니다.

'''
열
단위
주석입니다.
'''

1 + 1
# Out:
# 2

# %%
def solution(hello):
    """Connects to the next available port.

    Args:
      minimum: A port value greater or equal to 1024.

    Returns:
      The new minimum port.

    Raises:
      ConnectionError: If no available port is found.
    """
    return hello

# %%
# 주석을 읽지 않고도 쉽게 읽을 수 있는 코드 (이것이 좋은 코드 이다.)

# %% [markdown]
# ## 변수의 type

# %%
def hello():
    return

class A:
    pass

a = 10     #int, 정수형
b = 10.1   #float, 실수
c = -1
d = True   #bool, 논리형(부울형, 참거짓형)
e = 'good'
f = '10'   #str, 문자열
g = 'kim'
h = 'honggildong'
i = 'example'
j = 10 + 2j #complex, 복소수
k = 0b110   #int, 2진법 
l = 0o56    #int, 8진법
m = 0xAC    #int, 16진법

##########
n = hello # function
o = print # bulit-in function
p = lambda x:x**2 # function
q = A # class
r = A() # instance
##########

print('type(10) : ', type(a))
print('type(10.1) : ', type(b))
print('type(-1) : ', type(c))
print('type(True) : ', type(d))
print('type(\'good\') : ', type(e))
print('\'10\' + \'10\' : ', f + f)
print('\'10\' * 3', f * 3)
print('\'hong\' + \'gildong\'', g + h)
print('type(\'gildong\') : ', type(h))
print('type(\'gildong100!!\') : ', type(i))
print('type(10 + 2j) : ', type(j))
print('type(0b110) : ', type(k))
print(k)
print('type(0o56) : ', type(i))
print(i)
print('type(0xAC) : ', type(m))
print(m)
# Out:
# type(10) :  <class 'int'>
# type(10.1) :  <class 'float'>
# type(-1) :  <class 'int'>
# type(True) :  <class 'bool'>
# type('good') :  <class 'str'>
# '10' + '10' :  1010
# '10' * 3 101010
# 'hong' + 'gildong' kimhonggildong
# type('gildong') :  <class 'str'>
# type('gildong100!!') :  <class 'str'>
# type(10 + 2j) :  <class 'complex'>
# type(0b110) :  <class 'int'>
# 6
# type(0o56) :  <class 'str'>
# example
# type(0xAC) :  <class 'int'>
# 172

# %% [markdown]
# ## 입력과 출력

# %%
x = input()   # 입력 받는 수는 문자열입니다.
print(x + x)
# Out:
# 10
# 1010

# %%
type(print) # builtin_function_or_method
# https://docs.python.org/3/library/functions.html
# Out:
# builtin_function_or_method

# %%
leehojun = print        # print도 변수이기 때문에 이처럼 하는 것이 가능하다.
leehojun('hello world') # print가 가리키는 주소를 leehojun도 가리키기 때문에 이처럼 된다.
id(print), id(leehojun)
# Out:
# hello world
# (140049521485520, 140049521485520)

# %%
print('hello world',  end='!')
print('hello world',  end='!')
print('hello world',  end='!')
# Out:
# hello world!hello world!hello world!

# %% [markdown]
# ## 변수의 속성
#
# * 영문과 숫자를 사용할 수 있지만, 숫자로 시작하지는 못합니다.
# * 특수문자를 사용하지 않아요.(언더바(_)는 사용합니다. 스네이크 표기법, 특수문자나 이미 사용 가능한 것들이 있기는 합니다. 권하지는 않습니다.)
# * 예약어는 사용하지 않습니다.(if, elif, while, for, etc)
# * 대소문자 구분합니다.
# * 언더바로만 사용하거나 언더바로 시작할 수 있습니다.
# * 대문자로 시작하는 변수를 사용할 수 있지만, 관습적으로 대문자로 시작하는 변수는 Class로 만들기 때문에 소문자로 시작하는 변수를 만들기를 권합니다. Class는 보통 파스칼 표기법을 따릅니다. 다만, 회사 컨벤션마다 다릅니다.

# %%
# hello1 = 100 은 가능하나
# 1hello = 100 은 불가능하다.

# %%
hello_world = 10 # 스네이크 표기법이 컨벤션으로 있는 경우가 많습니다.
helloWorld = 10 # 카멜 표기법 (JavaScript에서 많이 사용)
# 𝝅 = 3.14 # error가 안나지만, 사회생활 힘들어진다.
# 𝝅 * 100 # 사회생활 힘들어짐.

# %%
# 아래와 같이 반복 안에서 해당 변수를 전혀 사용하지 않는 경우
# (관습적으로) 많이 사용됩니다. 
# _ = 100 이렇게는 잘 사용되지 않습니다. 권장하지 않습니다.
for _ in range(2):
  print('hello')
  print(_+_)
# Out:
# hello
# 0
# hello
# 2

# %% [markdown]
# ## 변수

# %%
# CS에서 변수란? 포스트잇(메모리 공간을 가리키는)
a = 10 # a -> 10
a = 20 # a -> 20

# %%
a = 10
b = a
a= 20
b # colab은 마지막에 print 생략가능
# 여기서 b는 a를 가리킨게 아니라 a가 가리킨 10을 가리켰기 때문에 결과는 10으로 나온다.
# Out:
# 10

# %%
id(a) # id는 주소값을 가리키는 함수
# Out:
# 140469466467216

# %%
id(b)
# Out:
# 140469466466896

# %%
a = 10
b = a

# %%
id(a), id(b)
# Out:
# (140469466466896, 140469466466896)

# %%
a is b
# Out:
# True

# %%
a = 10
b = 10

# %%
id(a), id(b) # a와 10 / b와 10은 모두 다른 공간으로 생성되지만, 주소는 똑같이 나온다.
# Out:
# (140469466466896, 140469466466896)

# %%
a = 257
b = 257

# %%
id(a), id(b) # 하지만 이곳에서는 a와 b의 주소가 다르게 나온다.
# Out:
# (140468201908880, 140468201910000)

# %%
a is b
# Out:
# False

# %%
# Python은 자체적으로 속도를 높이기 위한 여러가지 노력들을 해왔다.
# 그래서 0 ~ 256은 먼저 메모리에 적재를 합니다.

# %% [markdown]
# * 변수의 타입
# * 변수의 타입은 왜 있는 것일까?
#   * 효율적인 측면
#   * 관리적인 측면

# %%
'a' + 'a'
# Out:
# 'aa'

# %%
# 왜 이어 붙였는가?

# %%
# 우리가 통념적으로 생각하는 문자열의 연산을 Python이라는 언어에 구현해놓은 것이다.
# 메직 메서드를 통해서 이런 '약속'들을 구현하게 된다.

# %% [markdown]
# ## int(정수)

# %%
10, -10 # 정수
10.0 # 실수
# 10.0은 수학적으로 실수, 정수 모두 가능하더라도 컴퓨터 언어로는 실수이다.
# Out:
# 10.0

# %%
a = 10

# %%
type(a) # a라는 변수의 어떤 타입으로 처리하고 있는지 알려달라는 명령어
# Out:
# int

# %%
dir(a) # dir은 a가 가지고 있는 모든 속성들을 달라고 하는 명령어
# 항상 type와 dir을 찍어 볼 것.
# a를 활용하는 입장에서는 __가 있는 것보다 아래의 __가 없는 속성들이 중요하다.
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
# ...

# %%
int('100') + int('100')
# Out:
# 200

# %%
a = 0b110   #int, 2진법 / 0,1 (숫자를 2개만 쓰는 것)
b = 0o56    #int, 8진법 / 0 ~ 7 (숫자를 8개만 쓰는 것)
c = 0xAC    #int, 16진법 / 0 ~ 9, a ~ f (숫자와 문자를 16개만 쓰는 것)

type(a), type(b), type(c)
# Out:
# (int, int, int)

# %%
# 287 == (10^2) * 2 + (10^1) * 8 + (10^0) * 7 ## 10진법
# 110 == (2^2) * 1 + (2^1) * 1 + (2^0) * 0 => 4 + 2 + 0 => 6 ## 2진법
# ffffff(화이트), 000000(블랙) ## 색상은 16진법을 사용함
# AC ==  (16^1) * A + (16^0) * C => 160 + 12 => 172

# %%
a, b, c
# Out:
# (6, 46, 172)

# %%
bin(6), oct(46), hex(172)  
# 바이너리, 2진수로 만듦 # 옥타. 8진수로 만듦 # 헥사, 16진수로 만듦
# Out:
# ('0b110', '0o56', '0xac')

# %%
0.1 + 0.2 
# 모든 언어 공통(2진법으로 변환했을 때 무한대수가 발생된다.)
# 부동소수점 오차 발생이라고 한다.
# Out:
# 0.30000000000000004

# %%
int('0b110', 2), int('0o56', 8), int('0xac', 16)
# Out:
# (6, 46, 172)

# %%
class int(int):
    def __add__(self, a):
        return self * a

int('10') + int('10')
# Out:
# 100

# %%
class int(int):
    def __add__(self, a):
        return 'leehojun'

int('10') + int('10')
# Out:
# 'leehojun'

# %% [markdown]
# ## float(실수)

# %%
a = 10.1
type(a)
# Out:
# float

# %%
dir(a)
# Out:
# ['__abs__',
#  '__add__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getformat__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__le__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__setformat__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  'as_integer_ratio',
#  'conjugate',
#  'fromhex',
#  'hex',
#  'imag',
#  'is_integer',
#  'real']

# %%
type(10 + 10.1) # 다른 언어는 error
# Out:
# float

# %% [markdown]
# ## str(문자열)
#
# * 왜 문자'형'이 아니라 문자'열' 일까?

# %%
a = 'Hello World'

type(a)
# Out:
# str

# %%
b = 'CEO leehojun'

b[0] # 대괄호 안에 들어간 값을 index라고 하고, 이렇게 index로 값을 호출하는 것을 indexing이라고 한다.
b[1]
# Out:
# 'E'

# %%
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
'capitalize','casefold','center','count','encode','endswith','expandtabs',
'find','format','format_map','index','isalnum','isalpha','isascii','isdecimal',
'isdigit','isidentifier','islower','isnumeric','isprintable','isspace','istitle',
'isupper','join','ljust','lower','lstrip','maketrans','partition','removeprefix',
'removesuffix','replace','rfind','rindex','rjust','rpartition','rsplit','rstrip',
'split','splitlines','startswith','strip','swapcase','title','translate','upper','zfill'

# %% [markdown]
# * 모든 Line은 79자 (Characters)로 제한하기를 권고

# %%
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa => 80자
# 아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아 => 42자면 한글은 넘어간다.
# line에 딱 맞춰 들어간 것을 볼 수 있다.
# 강제사항은 아니다.
# 띄어쓰기 4번도 강제사항은 아니다.
# pep8, pep20에 기술되어 있다.
# pep란? : Python Enhancement Proposal
# pep8이란? Style Guide for Python Code
# pep20이란? The Zen of Python

# %%
for i in range(10):
        print(i)
        print(i + i)

# %%
a
# Out:
# 'Hello World'

# %%
a.lower() # 문자열을 모두 소문자로 변경 (데이터 분석에는 lower이 많이 쓰임)
# Out:
# 'hello world'

# %%
a.upper() # 문자열을 모두 대문자로 변경
# Out:
# 'HELLO WORLD'

# %%
a.islower() # 전부 다 소문자로 이루어져 있는가? (이것도 많이 쓰임)
# Out:
# False

# %%
'hello'.islower()
# Out:
# True

# %%
'hello'.isupper() # 모두 대문자로 이루어져 있는가?
# Out:
# False

# %%
'HELLO'.isupper()
# Out:
# True

# %%
'123'.isdigit() # 숫자인가? (많이 쓰임)
# Out:
# True

# %%
'123'.isalpha() # 문자열인가? (많이 쓰임)
# Out:
# False

# %%
# 배우지 않은 문법을 이해하려 노력하지는 마세요.
# i.isdigit() 이것만 집중해서 보시면 됩니다.
# 아래 문자열 중 숫자만 다 더해라
s = 0
for i in '123abc7584739203lsdlfei123ndsdf':
    if i.isdigit():
        s = s + int(i)
s
# Out:
# 60

# %%
' '.isalpha()
# Out:
# False

# %%
'hello world'.isalpha()
# Out:
# False

# %%
'hello world'.count('l')
# Out:
# 3

# %%
# 1부터 100000까지 8의 갯수를 모두 세어라
'[1,2,3,4,5]'.count(',')
str(list(range(10001))).count('8') # list가 대괄호 형식으로 만들어줌
# Out:
# 4000

# %%
'leehojun'.center(10) # 괄호 안에 글자에 맞춰줌
'leehojun'.center(20)
'leehojun'.center(20,'!')
'leehojun'.center(20,'-') # 뒤에 글자를 추가하면 기본인 공백 대신 글자에 맞게 채워줌
# Out:
# '------leehojun------'

# %%
'paullab CEO leehojun'.rjust(30) #오른쪽 정렬
'paullab CEO leehojun'.ljust(30) #왼쪽 정렬
'paullab CEO leehojun'.center(30)#가운데 정렬
# Out:
# '     paullab CEO leehojun     '

# %%
'leehojun'.index('h')
# 'leehojun'.index('z') # 못 찾으면 error
# Out:
# 3

# %%
'leehojun'.find('h')
# 'leehojun'.find('z') # 못 찾으면 -1
# Out:
# 3

# %%
# 그러면 어떤 코드가 더 좋은가요?
# 정답은 없습니다. 여러분 코드 의도에 맞게 코딩하실 필요가 있습니다.
# find의 -1은 True이고 index의 오류는 False이기 때문에 이런 것을 생각할 필요가 있다.

# %%
'hello'.count('')
# Out:
# 6

# %%
# https://stackoverflow.com/questions/40192449/why-are-str-count-and-lenstr-giving-different-output
a = ''
print(len(a))
print(a.count(''))
# 위 사이트 설명으로는 ^t^e^s^t^라서 test.count('')는 5가 나온다고 설명
# '' + ''은 ''하나만 나오기 때문에 count를 했을 경우 1이 나온다.
# Out:
# 0
# 1

# %%
a = 'a'
print(len(a))
print(a.count(''))
# ' t e s t ' => 빈 문자가 5번 카운팅
# Out:
# 1
# 2

# %%
# 중요하지 않다.
'paullab CEO leehojun.'.endswith('.') # 마침표로 끝났느냐?
# Out:
# True

# %%
'paullab CEO leehojun.'.endswith('!') # 느낌표로 끝났느냐?
# Out:
# False

# %%
'paullab CEO leehojun.'[-1] == '.'
# Out:
# True

# %%
''.join(['hello', 'world', 'hojun'])
'!'.join(['hello', 'world', 'hojun'])
'-'.join(['010', '5044', '2903']) # 이호준 강사님 전화번호
# join하려면 string 형이어야 한다.
# ''.join[ 010 , 5044, 2903 ] 이런 숫자는 오류가 발생한다.
# Out:
# '010-5044-2903'

# %%
# % 용법이 최초에 있었다. -> 너무 오래 된 거라 기억에서 지워도 괜찮다.
age = 11
name = 'hojun'
print('name %s이고 age는 %d'%(name, age)) # %s는 string이라 문자 d는 숫자
# Out:
# name hojun이고 age는 11

# %%
# 이후 format 용법이 생겼다.
age = 11
name = 'hojun'
height = 179.9999
print('name {} age {}'.format(name, age))
print('name {0} age {1}'.format(name, age)) # format 괄호안에 name이 0번째, age가 1번째이다.
print('name {1} age {1}'.format(name, age)) # 중괄호 안에 숫자를 넣어서 순서를 변경할 수도 있다.
txt = 'name {} age {}'
print(txt.format(name, age)) # format이 메서드 이기 때문에 앞에 있는 것은 string이다.


#@ print('height {}'. format(height))
#@ print('height {height:.2f}'. format(height=179.99)) # :.2f는 두번째 자리까지 표현한다는 것
#@ # 179.9999로 하면 부동소수점 때문에 180.00으로 반올림해서 표현함
# 위 @가 있는 height 부분은 나중에 또 1시간으로 따로 정리하는 것으로 함
# Out:
# name hojun age 11
# name hojun age 11
# name 11 age 11
# height 179.9999
# height 179.99

# %%
# 이후 f-string 용법이 생겼다.(3.6 version에서 새로 나옴)
age = 11
name = 'hojun'
print(f'name: {name} age: {age}')
# Out:
# name: hojun age: 11

# %%
'hello world'.find('l')
'hello world'.rfind('l')
'hello world'.rindex('l') # r은 오른쪽에서 찾는 다는 것
# Out:
# 9

# %%
'           hello world            '.strip() # 공백 제거, rstrip, lstrip 있음 (많이 사용)
# Out:
# 'hello world'

# %%
'100'.zfill(10) # 10자리를 채운다.
# Out:
# '0000000100'

# %%
'010-0000-0000'.split('-') # 괄호 안에 글자로 나눠서 리스트를 만들어 줌
'010!-0!000-0!000'.split('!')
# Out:
# ['010', '-0', '000-0', '000']

# %%
'paullab CEO leehojun'.replace('CEO', 'CTO') # string이 나와야 string 메서드 체이닝을 할 수 있다.

# %%
'paullab CEO leehojun'.replace('CEO', 'CTO').replace('hojun', 'gildong') # 메서드 체이닝
# CTO를 123으로 변경한다면 오류가 발생한다. 이유는 string 형이 아니기 때문이다.
# Out:
# 'paullab CTO leegildong'

# %%
# '010-0000-0000'.split('-').zfill(10) 
# error 앞에서 진행한 split이 list를 반환하기 때문에 zfill을 사용할 수 없습니다.

'010-0000-0000'.split('-').count('0000') 
# 이건 가능합니다. count는 str에도 있지만 list에도 있어요.
# Out:
# 2

# %%
# 이스케이프 문자 : \n(줄바꿈), \t(탭, 현재시간)

암호 = '''  + +-+ -+-  
  ++ -- +-+  
  ++-+ -+ -  
  + ++-+ -+ '''
print(암호)
# Out:
#   + +-+ -+-
#   ++ -- +-+
#   ++-+ -+ -
#   + ++-+ -+

# %%
# 지금 이 코드에서는 strip을 할 이유가 없지만 앞 뒤 공백만 제거해야 할 때가 있습니다.
이진수 = 암호.split('\n')[0].strip().replace(' ', '').replace('+', '1').replace('-', '0')
int(이진수, 2)
# 위 해석 방식은 암호의 줄 바꾸기를 없애고(split(\n)), 양쪽 공백을 없애고(strip)
# replace로 전체 공백을 없애고, +, -를 1, 0으로 바꾼뒤 이진수를 16진수로 바꿔
# 알파벳을 구해 암호를 해독한다.
# Out:
# 106

# %%
chr(106) # 유니코드표에서 숫자로 문자 출력
ord('j') # 유니코드표에서 문자를 숫자로 출력

# %%
# 아래 3개는 모두 string 입니다.

a = 10

'hello world {}'.format(a)
f'hello world {a}'
r'hello world'
# Out:
# 'hello world'

# %%
r'hello world' # raw : 날것의, 이스케이프 단어도 모두 표시해줌
'hello world'
# Out:
# 'hello world'

# %%
print(r'hello \n world')
# Out:
# hello \n world

# %%
print('hello \n world')
# Out:
# hello
#  world

# %%
# 참고만 해주세요.
규칙테이블 = str.maketrans('vlo','345') # vlo와 345의 문자열 수가 같아야 한다. 1:1 매칭이 되야 함
'weniv hello world'.translate(규칙테이블) #어떤 규칙을 정하는것
# Out:
# 'weni3 he445 w5r4d'

# %% [markdown]
# ## 문자열의 활용

# %%
name = 'Guido van Rossum'
print(name[0])
print(name[1])
print(name[2])
# Out:
# G
# u
# i

# %%
s = '위니브 월드 외각에 살고 있는 생선가게...'
# s[start:stop:step]
# 6이면 6번째 전까지만 잘라냄. 공백도 수 포함
s[0:6], s[:6], s[4:6], s[7:9], s[s.find('외각'):s.find('외각')+2], s[-1], s[:-5], s[:-1], s[::2], s[::-1]
# s[:-1]는 마지막 글자만 제거하기 위해 많이 사용된다.
# s[::2]는 step을 2로 한다는 의미이다.
# Out:
# ('위니브 월드',
#  '위니브 월드',
#  '월드',
#  '외각',
#  '외각',
#  '.',
#  '위니브 월드 외각에 살고 있는 생선',
#  '위니브 월드 외각에 살고 있는 생선가게..',
#  '위브월 각 고있 선게.',
#  '...게가선생 는있 고살 에각외 드월 브니위')

# %%
s = 'leehojun'

s+s
s*3
# s/s   #error
# s//s  #error
# s-s   #error

# %% [markdown]
# ## 형변환

# %%
print(type(int(3.5)))
print(int(3.5))
print(type(float(3)))
print(float(3))
print(type(str(3)))
print(str(3))
# Out:
# <class '__main__.int'>
# 3
# <class 'float'>
# 3.0
# <class 'str'>
# 3

# %%
x = input('Insert the number.')
y = input('Insert the number.')
print(x + y)
print(type(x))
print(type(y))
# Out:
# Insert the number.10
# Insert the number.10
# 1010
# <class 'str'>
# <class 'str'>

# %%
l = [10, 20, 15, 17, None]
len(l)
# Out:
# 5

# %%
sum([10,20,30,40], 100), sum([[1,2,3], [4,5,6]], [])
# Out:
# (200, [1, 2, 3, 4, 5, 6])

# %%
# 숫자 : 0외의 다른 숫자는 다 참
# 문자 : ''외의 다른 문자는 다 참
# 리스트 : []외에 다른 리스트는 다 참
# 공백도 참
# None : 아무것도 없음을 명시 -> 거짓

print("bool('test') : ", bool('test'))
print("bool(1) : ", bool(1))
print("bool(0) : ", bool(0))
print("bool(-1) : ", bool(-1))
print("bool(' ') : ", bool(' '))
print("bool('') : ", bool(''))
print("bool(None) : ", bool(None))
# Out:
# bool('test') :  True
# bool(1) :  True
# bool(0) :  False
# bool(-1) :  True
# bool(' ') :  True
# bool('') :  False
# bool(None) :  False

# %%
int()
float()
str()
bool()
list('leehojun')
tuple('leehojun')
s=[('name','leehojun'),('age',10)]
d=dict(s)
d
set('leehojun') # 중복이 제거된 상태로 set 자료형이 된다.
# Out:
# {'e', 'h', 'j', 'l', 'n', 'o', 'u'}

# %%
num = 1234567890
list(str(num))[3]
# Out:
# '4'

# %% [markdown]
# # 연산

# %% [markdown]
# ## 산술연산자

# %%
a = 10
b = 3
print(a + b)
print(a - b)
print(a / b)    # flaot
print(a // b)   # int
print(a * b)
print(a ** b)
print(a % b)    # 나머지 출력
# Out:
# 13
# 7
# 3.3333333333333335
# 3
# 30
# 1000
# 1

# %% [markdown]
# ## 비교연산자

# %%
a = 10
b = 3

print(a == b) # 같은가?
print(a != b) # 다른가?
print(a > b)
print(a >= b)
print(a < b)
print(a <= b)
# Out:
# False
# True
# True
# True
# False
# False

# %% [markdown]
# ## 논리연산

# %%
# True : 1
# False : 0
# and : 논리곱
# or : 논리합
# not : 부정

# %%
# True and Flase
# 둘 중 하나라도 False라면 False
# and는 위와 같은 속성 때문에 둘 다 만족해야하는 '조건'에 사용합니다.

for i in range(101):
  if i % 3 == 0 and i % 5 == 0:
    print(i)
# Out:
# 0
# 15
# 30
# 45
# 60
# 75
# 90

# %%
for i in range(101):
  if i % 3 == 0 or i % 5 == 0 and i % 2 == 0:
    print(i)
# Out:
# 0
# 3
# 6
# 9
# 10
# 12
# 15
# 18
# 20
# 21
# 24
# 27
# 30
# 33
# 36
# 39
# 40
# 42
# 45
# 48
# 50
# 51
# 54
# 57
# 60
# 63
# 66
# 69
# 70
# 72
# 75
# 78
# 80
# 81
# 84
# 87
# 90
# 93
# 96
# 99
# 100

# %%
10 and 20   # 모두 True 값이면 가장 마지막에 있는 값이 출력된다.
# Out:
# 20

# %%
0 and 20    # 처음이나 중간에 False 값이 있다면 그 값을 출력한다.
# Out:
# 0

# %%
1 and 2 and 3 and 0 and 5 and False and 20    
# 이 상황에서는 앞의 0이 출력 된다.
# 뒤의 False까지 확인하지 않음
# Out:
# 0

# %%
a = 'jin'
b = ''
a = a or 'woo'
b = b or 'woo'
a, b  # or은 둘 중 참인 것으로 넣는데 and와 마찬가지로 앞에서 순서대로만 확인한다.
# Out:
# ('jin', 'woo')

# %%
not True
# Out:
# False

# %%
not False
# Out:
# int

# %%
def err():
  1/0

test = 0 and err()
test
# Out:
# 0

# %%
# test = 10 and err()   # error 발생. 앞이 True이기 때문에 뒤에서 에러 발생
# test

# %% [markdown]
# ## 비트연산 (중요도 하)

# %%
# 2진수를 빨리 구하는 법 Tip
# 가장 가가운 2에 승수를 구한다.
# 거기에서 +-를 하면 된다.

7 & 5  # and 연산, 두 이진수 중 같은 것만 1

# 111
# 101
# -----
# 101
# Out:
# 5

# %%
7 | 5  # or 연산, 두 이진수 중 하나라도 1이 있으면 1

# 111
# 101
# -----
# 111
# Out:
# 7

# %%
# 문제

# ||```
14 | 7

# 1110
# 0111
# ----
# 1111
# ```||
# Out:
# 15

# %%
# 비트에서는 가장 앞 자리가 0이면 양수, 1이면 음수이다.
# ~는 비트를 뒤집는 이다. ex) 00000001 -> 11111110 : 1 -> 0

# 8 bit

# 00000000
# 11111111

# 256개
# 0 ~ 255까지 사용? 음수사용 불가!
# 그래서 부호비트를 사용하는데 ~는 비트단위로 전환을 하는 것입니다.
# 00001010 -> not을 취하게 되면 
# 11110101 -> 음수 표기법으로 9가 나오게 되는 것
# 비트는 크게 중요하지 않음!

# 보수법이라고 함

~-10  # ~ 뒤에 값에다 +1 하고 x(-1)한 것과 같다.
# Out:
# 9

# %%
~~-10
# Out:
# -10

# %%
~~10.1  # 이렇게 했을 경우 10이 출력되는 언어도 있지만, 파이썬에서는 오류이다. 
# 몰라도 괜찮다.

# %%
a = 7   
b = 2   

print(a << b)   # 111을 <-으로 두칸 미는 것 즉, 11100이 돼서 28이나옴
# Out:
# 28

# %%
a = 7   
b = 2   

print(a >> b)   # 111을 ->으로 두칸 미는데 오른쪽은 벽이라 없어져서 1만 남음.
# Out:
# 1

# %% [markdown]
# ## 아름다운 코드 (데코레이터) (심심해서 함)

# %%
#데이터 분석에서 쓰일만한 데코레이터
def 숫자로변환(func):
    def new_func(l):
        print(func(list(map(int, l))))
    return new_func

@숫자로변환
def 평균(l):
    return sum(l) / len(l)

평균([1, 2, 3, 4, 5])
평균(['1', '2', '3', 4, 5])
평균(['1', '2', '3', '4', '5'])
# Out:
# 3.0
# 3.0
# 3.0

# %%
d = {'one':10, 'two':20, 'three':30}
d.values()
max(d.values())   # value를 얻음
max(d, key=d.get) # key를 얻음
# Out:
# 'three'

# %% [markdown]
# ## 할당연산

# %%
a = 10
a = a + 10
a
# Out:
# 20

# %%
a = 10
a += 10
a
# Out:
# 20

# %% [markdown]
# ## 식별연산

# %%
a = 10
b = 10
print(id(a), id(b))

a is b , a is not b     # is는 객체 메모리의 위치(주소)가 같다면 True를 반환함
# Out:
# 140049521695312 140049521695312
# (True, False)

# %%
a = 999
b = 999
print(id(a), id(b))

a is b
# Out:
# 140048255278000 140048255278032
# False

# %%
a = [1,2,3]
b = [1,2,3]
print(id(a), id(b))

a is b    # 주소 비교를 했기 때문에 False 반환
# Out:
# 140048254533120 140048237531584
# False

# %%
# Python 언어에서는 True가 나오지만, 다른 언어에서는 False가 나올 수도 있음.
a == b    # 값만 비교했기 때문에 True 반환.

# 사용자는 값을 비교할 것이라고 생각했기 때문에 로직을 값만 비교하게 만듦.
# Out:
# True

# %% [markdown]
# ## 멤버연산

# %%
# 안에 수가 있는지 물어봄. 많이 쓰임!!
10 in [1,2,3]
# Out:
# False

# %%
10 in [1,2,3,10]
# Out:
# True

# %%
'one' in {'one':10, 'two':20}
# True는 받을 수 있지만, value를 받을 수는 없다.
# Out:
# True

# %%
20 in {'one':10, 'two':20}
# Out:
# False

# %%
'l' in 'hello'
# Out:
# True

# %%
10 in {10, 20, 30}    # 요소는 True를 반환함
# Out:
# True

# %%
{10} in {10, 20, 30}  # 부분집합은 False를 반환함
# Out:
# False

# %%
{10, 20} in {10, 20, 30}
# Out:
# False

# %%
a={'key':'value', 'key2':'value'}
'key' in a              # True
'value' in a            # False
('key', 'key2') in a    # False
{'key', 'key2'} in a    # Error

# %% [markdown]
# ## 그리디 알고리즘
#
# * 욕심쟁이 알고리즘이라고 불립니다.
# * 가장 최선을 선택한 것이 최종적으로도 가장 최선의 선택이다.

# %%
# 10000원을 들고 가서 1200원짜리 아이스크림을 먹었을 때 잔돈의 갯수가 가장 적은 경우를 구하라.

잔돈 = 8800

오천원갯수 = 잔돈 // 5000
잔돈 = 잔돈 - 오천원갯수 * 5000

천원갯수 = 잔돈 // 1000
잔돈 = 잔돈 - 천원갯수 * 1000

오백원갯수 = 잔돈 // 500
잔돈 = 잔돈 - 오백원갯수 * 500

백원갯수 = 잔돈 // 100
잔돈 = 잔돈 - 백원갯수 * 100

print(f'오천원은 {오천원갯수}개, \
천원은 {천원갯수}개, \
오백원은 {오백원갯수}개, \
백원은 {백원갯수}개를 거슬러 드립니다.')
# 위 문장처럼 길어진 경우에는 중간에 \를 뒤에 쓰고 내리면 된다.

# 추가로 줄이 달라도 데이터는 입력된다.
data = [10,
        
        20,
        
        30]
data
# Out:
# 오천원은 1개, 천원은 3개, 오백원은 1개, 백원은 3개를 거슬러 드립니다.
# [10, 20, 30]

# %% [markdown]
# # 함수

# %% [markdown]
# * 함수리뷰
#
# 테스트 주도개발, 디자인 주도개발, 도메인 주도개발, 월급 주도개발 다 아닙니다. 동작 주도개발(일단 여러분에게 요구되는 사항)입니다. 그럼에도 불구하고 80점 짜리 코드는 되어야 합니다.
#
# "프로그래머에게 요구되는 것은 100점이 아닌 80~90점짜리 프로그램을 기한 내에 완성하는 일" - 나카지마 사토시
#
# "아무리 급해도 항상 80점짜리 소프트웨어를 개발할 수 있는지가 중요하다" - 인프랩 이동욱
#
# ---
#
# 마틴이 클린코드에서 주장한 원칙 5개(solid)
# SRP : 단일 책임 원칙(각 클래스(또는 모듈, 오브젝트)는 하나의 정보만 가지게 만들어야 한다)
# OCP : 개방 폐쇠 원칙(확장에는 열려 있으며, 변경에는 닫혀 있어야 한다)
# LSP : 리스코프 치환 원칙(인터페이스의 서브타이핑은 인터페이스에 정의된 형태를 최대한 유지)
# ISP : 인터페이스 분리 원칙(인터페이스는 최소한으로 유지)
# DIP : 의존 관계 역전 원칙(상위 레벨의 모듈이나 인터페이스가 서브 클래스나 타이핑에 영향을 받아서는 안된다)
#
# ---
#
# 개발자들이 가장 많이 사용하는 개발 원칙
# KISS : 최대한 단순함을 유지하라
# DRY : 똑같은 기능, 코드를 반복하지 마라
# YAGNI : 그 기능이 필요하기 전까지는 미리 만들지 마라
#
# ---
#
# 클린소프트웨어 - 악취
# 경직성 : 프로그램 변경이 어렵다. 원하는 곳만 변경하면 장애가 난다.
# 취약성 : 프로그램 변경시 아무런 연관이 없는 부분에서 장애 발생
# 부동성 : 재사용할 수 있는 컴포넌트로 구분이 어려움
# 점착성 : 개발 환경이 비효율적
# 불필요한 복잡성 : 직접 효용이 없는 구조가 디자인에 포함
# 불필요한 반복 : 단일 추상 개념으로 통합할 수 있는 반복구조 포함
# 불투명성 : 직접 만든 사람이 아닌 다른 사람이 코드를 읽고 이해하기 힘들다
#
# 작은 효율성에 대해서는, 말하자면 97% 정도에 대해서는 잊어버려라. 섣부른 최적화는 모든 악의 근원이다. - 도널드 커누스
#
# 패스트캠퍼스 CTO님
# 1. 일단 동작하게 만든 다음 더 좋게 만들어라
# 2. 언제나 발견했을 때보다 깨끗하게 해놓고 캠핑장을 떠나라
# 3. 바퀴를 새로 발명하는 일의 좋은 점은 둥근 바퀴를 얻을 수 있다는 점입니다.
#
# ---
#
# 가장 많이 실수 하시는 것
# 폴더 트리 : 재사용 할 수 있는 것은 폴더로 모아주세요.
# 반복 : 재사용 가능한 코드는 컴포넌트화 해주세요.
# API : 컴포넌트 안에 넣지 말고 파일로 만들어 재사용해주세요.
#
# 그 외 코드 리뷰
# 1. 기능이 완료 되었는지 실행시켜볼 수 있다면 실행시켜 보면서 확인
# 2. 가독성과 유지보수
# 3. 예외처리

# %% [markdown]
# * 어떻게 하면 더 좋은 코드를 작성할 수 있는가?
# 마틴이 클린코드에서 주장한 원칙 5개(solid)
# SRP : 단일 책임 원칙(각 클래스(또는 모듈, 오브젝트)는 하나의 정보만 가지게 만들어야 한다)
# OCP : 개방 폐쇠 원칙(확장에는 열려 있으며, 변경에는 닫혀 있어야 한다)
# LSP : 리스코프 치환 원칙(인터페이스의 서브타이핑은 인터페이스에 정의된 형태를 최대한 유지)
# ISP : 인터페이스 분리 원칙(인터페이스는 최소한으로 유지)
# DIP : 의존 관계 역전 원칙(상위 레벨의 모듈이나 인터페이스가 서브 클래스나 타이핑에 영향을 받아서는 안된다)

# %%
def hello():
  return 10
print(hello())
# Out:
# 10
